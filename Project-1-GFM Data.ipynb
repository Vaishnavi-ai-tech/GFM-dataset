# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Data

# %%
gfm = pd.read_csv('gfm_data.csv')
gfm
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# ...

# %% [markdown]
# # Introductory Details of Data

# %% [markdown]
#  EDA       : This is a data exploration technique to understand the various aspects of data.
#
#  Objective : 1) Helps us in identifying the faulty points in data. So that we can easily remove then and clean our data.
#              2) Helps us to understand the relationship between the variables which gives us a wider perspective on the data.
#
#  Steps     : 1) Understand the data.
#              2) Clean the data.
#              3) Analysis of relationship between variables.

# %%
gfm.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising Number_of_Donors FB_Shares  \
# 0      2297930.0  3000000.0                   93            72.5K      118K
# 1      1862040.0  1000000.0                  205            21.9K     71.7K
# 2       954793.0  1200000.0                  215            18.3K     16.4K
# 3       673179.0  1000000.0                  131            10.3K     21.3K
# 4       570529.0   750000.0                  175            24.3K      5.5K
#
# ...

# %%
gfm.tail()
# Out:
#     Category                                       Title          Location  \
# 833   Wishes  Juneteenth Women of Color Scholarship Fund      Brooklyn, NY
# 834   Wishes  All-Terrain Wheelchair for Benjamin Wimett       Brandon, VT
# 835   Wishes                           Martha's Daughter       Amherst, MA
# 836   Wishes                      Financial Difficulties  Johnson City, TN
# 837   Wishes                      Our Roots - Yahchouche     Santa Ana, CA
#
#      Amount_Raised      Goal  Days_of_Fundraising Number_of_Donors FB_Shares  \
# 833        17348.0   20000.0                  160              366       214
# 834        19300.0   17000.0                  200              279      2.5K
# 835        21435.0  300000.0                  110              318       868
# 836        16405.0   70000.0                  173              148       379
# 837        17905.0   50000.0                  147               45       242
#
# ...

# %%
gfm.shape
# Out:
# (838, 9)

# %%
gfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             838 non-null    object
#  1   Title                838 non-null    object
#  2   Location             838 non-null    object
#  3   Amount_Raised        838 non-null    float64
#  4   Goal                 838 non-null    float64
#  5   Days_of_Fundraising  838 non-null    int64
#  6   Number_of_Donors     838 non-null    object
#  7   FB_Shares            838 non-null    object
#  8   Text                 838 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 59.0+ KB

# %%
print(gfm.columns)
# Out:
# Index(['Category', 'Title', 'Location', 'Amount_Raised', 'Goal',
#        'Days_of_Fundraising', 'Number_of_Donors', 'FB_Shares', 'Text'],
#       dtype='object')

# %% [markdown]
# # Statistical Insights

# %%
gfm.describe()
# Out:
#        Amount_Raised          Goal  Days_of_Fundraising
# count   8.380000e+02  8.380000e+02           838.000000
# mean    1.156295e+05  1.541021e+05           134.819809
# std     3.216969e+05  3.025483e+05            49.570169
# min     6.370000e+02  1.000000e+00            35.000000
# 25%     1.951200e+04  2.000000e+04            94.250000
# 50%     5.287100e+04  7.500000e+04           140.000000
# 75%     1.233572e+05  1.500000e+05           176.000000
# max     6.750030e+06  3.000000e+06           447.000000

# %% [markdown]
# n unique values: It is nothing but a function which returns a series with a number of distinct observations that were requested access.

# %%
gfm.nunique()
# Out:
# Category                14
# Title                  835
# Location               507
# Amount_Raised          823
# Goal                   132
# Days_of_Fundraising    178
# Number_of_Donors       458
# FB_Shares              440
# Text                   835
# dtype: int64

# %%
gfm['Category'].unique()
# Out:
# array(['Medical', 'Memorial', 'Emergency', 'Animals', 'Business',
#        'Community', 'Competition', 'Creative', 'Event', 'Faith', 'Family',
#        'Newlywed', 'Sports', 'Wishes'], dtype=object)

# %%
gfm.isnull().sum()
# Out:
# Category               0
# Title                  0
# Location               0
# Amount_Raised          0
# Goal                   0
# Days_of_Fundraising    0
# Number_of_Donors       0
# FB_Shares              0
# Text                   0
# dtype: int64

# %% [markdown]
# # Relationship Analysis

# %% [markdown]
# First step i would like to do is correlation matrix because it gives us wider perspective on what exactly are we dealing with here.
#
# A correlation matrix is a table showing correlation coefficients between variables and each cell in the table shows the correlation between two variables.
#
# Correlation matrix is used to summarize data as an input into a more advanced analysis and also as a diagnostic for advanced analysis.

# %%
correlation = gfm.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q1. Define a function named convert_units which converts a string representation of a number to an integer. This function should work whether or not the string representation has a ‘K’ in it (representing thousands).

# %%
gfm['FB_Shares']=gfm['FB_Shares'].map(lambda st: float(st.replace("K","")))
gfm['FB_Shares']=gfm['FB_Shares']*1000

gfm['Number_of_Donors']=gfm['Number_of_Donors'].map(lambda st: float(st.replace("K","")))
gfm['Number_of_Donors']=gfm['Number_of_Donors']*1000

gfm
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# ...

# %% [markdown]
# ### Q2. Overwrite the columns for Number_of_Donors and FB_Shares with columns of the same name, but contain integers instead strings, The dataframe should still be names gfm_data.

# %%
gfm_data = pd.DataFrame(gfm['Number_of_Donors'])
print(gfm_data)
# Out:
#      Number_of_Donors
# 0             72500.0
# 1             21900.0
# 2             18300.0
# 3             10300.0
# 4             24300.0
# ..                ...
# 833          366000.0
# 834          279000.0
# 835          318000.0
# 836          148000.0
# 837           45000.0
#
# [838 rows x 1 columns]

# %%
gfm_data = pd.DataFrame(gfm['FB_Shares'])
print(gfm_data)
# Out:
#      FB_Shares
# 0     118000.0
# 1      71700.0
# 2      16400.0
# 3      21300.0
# 4       5500.0
# ..         ...
# 833   214000.0
# 834     2500.0
# 835   868000.0
# 836   379000.0
# 837   242000.0
#
# [838 rows x 1 columns]

# %% [markdown]
# ### Q3.  3. Create a new dataframe called gfm_campaigns that has the same columns as gfm,plus two more:
#          1) Proportion_Raised, which has the proportion of the overall goal that the campaign raised. This proportion should be             rounded (not truncated) to 3 decimal places.
#          2) Average_Donation_Amount, which has the average donation amount per donor. Since this is a dollar amount, it should             be rounded (not truncated) to 2 decimal places.

# %%
gfm_campaigns = pd.DataFrame(gfm)
gfm_campaigns
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# ...

# %%
Proportion_Raised = gfm['Amount_Raised']/gfm['Goal']
Proportion_Raised
# Out:
# 0      0.765977
# 1      1.862040
# 2      0.795661
# 3      0.673179
# 4      0.760705
#          ...
# 833    0.867400
# 834    1.135294
# 835    0.071450
# 836    0.234357
# 837    0.358100
# Length: 838, dtype: float64

# %%
Average_Donation_Amount = gfm['Amount_Raised']/gfm['Number_of_Donors']      
Average_Donation_Amount
# Out:
# 0      31.695586
# 1      85.024658
# 2      52.174481
# 3      65.357184
# 4      23.478560
#          ...
# 833     0.047399
# 834     0.069176
# 835     0.067406
# 836     0.110845
# 837     0.397889
# Length: 838, dtype: float64

# %% [markdown]
# Adding New Columns

# %%
gfm_campaigns['Proportion_Raised'] = gfm_campaigns['Amount_Raised']/gfm_campaigns['Goal']
gfm_campaigns['Average_Donation_Amount'] = gfm_campaigns['Amount_Raised']/gfm_campaigns['Number_of_Donors']
gfm_campaigns.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising  Proportion_Raised  \
# 0      2297930.0  3000000.0                   93           0.765977
# 1      1862040.0  1000000.0                  205           1.862040
# 2       954793.0  1200000.0                  215           0.795661
# 3       673179.0  1000000.0                  131           0.673179
# 4       570529.0   750000.0                  175           0.760705
#
#    Number_of_Donors  FB_Shares  \
# 0           72500.0   118000.0
# ...

# %%
print(gfm_campaigns.columns)
# Out:
# Index(['Category', 'Title', 'Location', 'Amount_Raised', 'Goal',
#        'Days_of_Fundraising', 'Proportion_Raised', 'Number_of_Donors',
#        'FB_Shares', 'Text', 'Average_Donation_Amount'],
#       dtype='object')

# %% [markdown]
# ### Q4. Create a new dataframe called gfm_success, which has all the information from the gfm_campaigns dataframe plus a new column titled how_successful that indicates how successful a campaign was, depending on its Proportion_Raised. If x is the proportion raised, we use the table below to define how successful a campaign is.

# %%
How_Successful=[]
for x in gfm_campaigns['Proportion_Raised']:
    if 0.0<x<0.20:
        How_Successful.append("highy unsuccessful")
    elif 0.20<x<0.50:
        How_Successful.append("moderately unsuccessful")
    elif 0.50<x<0.80:
        How_Successful.append("moderately successful")
    elif 0.80<x<1.0:
        How_Successful.append("highly successful")
    else:
        How_Successful.append("extremly successfull")

# %%
New = {"Number_of_Donors":gfm_campaigns['Number_of_Donors'],"FB_Shares":gfm_campaigns['FB_Shares'],"Proportion_Raised":gfm_campaigns['Proportion_Raised'],"Average_Donation_Amount":gfm_campaigns['Average_Donation_Amount'],"How_Successful":How_Successful}
gfm_success = pd.DataFrame(New)
gfm_success
# Out:
#      Number_of_Donors  FB_Shares  Proportion_Raised  Average_Donation_Amount  \
# 0             72500.0   118000.0           0.765977                31.695586
# 1             21900.0    71700.0           1.862040                85.024658
# 2             18300.0    16400.0           0.795661                52.174481
# 3             10300.0    21300.0           0.673179                65.357184
# 4             24300.0     5500.0           0.760705                23.478560
# ..                ...        ...                ...                      ...
# 833          366000.0   214000.0           0.867400                 0.047399
# 834          279000.0     2500.0           1.135294                 0.069176
# 835          318000.0   868000.0           0.071450                 0.067406
# 836          148000.0   379000.0           0.234357                 0.110845
# 837           45000.0   242000.0           0.358100                 0.397889
#
#               How_Successful
# ...

# %% [markdown]
# ### Q5. CREATE A NEW DATAFRAME CALLED GFM, WHICH HAS ALL INFORMATION FROM THE GFM_SUCCESS DATAFRAME PLUS A NEW COLUMN CALLES NUM_CHARS WITH THE LENGTH OF THE TEXT DESCRIPTION FOR EACH CAMPAIGN, AS AN INT

# %%
gfm['Num_Chars']=gfm['Text'].str.len()
Frame = {"Number_of_Donors":gfm_campaigns['Number_of_Donors'],"FB_Shares":gfm_campaigns['FB_Shares'],"Proportion_Raised":Proportion_Raised,"Average_Donation_Amount":Average_Donation_Amount,"How_Successful":How_Successful,"Text":gfm['Text'],"Num_Chars":gfm['Num_Chars']}
gfm=pd.DataFrame(Frame)
gfm
# Out:
#      Number_of_Donors  FB_Shares  Proportion_Raised  Average_Donation_Amount  \
# 0             72500.0   118000.0           0.765977                31.695586
# 1             21900.0    71700.0           1.862040                85.024658
# 2             18300.0    16400.0           0.795661                52.174481
# 3             10300.0    21300.0           0.673179                65.357184
# 4             24300.0     5500.0           0.760705                23.478560
# ..                ...        ...                ...                      ...
# 833          366000.0   214000.0           0.867400                 0.047399
# 834          279000.0     2500.0           1.135294                 0.069176
# 835          318000.0   868000.0           0.071450                 0.067406
# 836          148000.0   379000.0           0.234357                 0.110845
# 837           45000.0   242000.0           0.358100                 0.397889
#
#               How_Successful  \
# ...

# %% [markdown]
# ### Q6. OVERWRITE THE TEXT COLUMN IN THE GFM DATAFRAME SO THAT ALL THE DESCRIPTIONS APPEAR IN LOWERCASE

# %%
gfm['Text'] = gfm['Text'].str.lower()
print(gfm['Text'])
# Out:
# 0      on august 23rd my son was shot multiple times ...
# 1      the navajo nation covid-19 fund has been estab...
# 2      on sunday, april 12, sylvia leroy, a pregnant ...
# 3      first, thank you for being here. tommy rivers ...
# 4      my name is melissa green and i am the mother o...
#                              ...
# 833    the need for community and collective healing ...
# 834    i am 35 years old and was born with cerebral p...
# 835    greetings,my name is nyanyika banda. i am a ch...
# 836    my wife, roni, and i have faced many  health c...
# 837    no matter where life has lead us, our past for...
# Name: Text, Length: 838, dtype: object

# %% [markdown]
# ### Q7. OVERWRITE THE TEXT COLUMN IN THE GFM DATAFRAME SO THAT ALL THE DESCRIPTIONS APPEAR IN LOWERCASE

# %%
for ind, row in gfm_campaigns.iterrows():
    gfm_campaigns.loc[ind, "impactful_words"] = len(row['Text']) > 1000
gfm_campaigns.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising  Proportion_Raised  \
# 0      2297930.0  3000000.0                   93           0.765977
# 1      1862040.0  1000000.0                  205           1.862040
# 2       954793.0  1200000.0                  215           0.795661
# 3       673179.0  1000000.0                  131           0.673179
# 4       570529.0   750000.0                  175           0.760705
#
#    Number_of_Donors  FB_Shares  \
# 0           72500.0   118000.0
# ...

# %% [markdown]
# ### Q8.CREATE A NEW DATAFRAME CALLED GFM_IMPACTFUL, WHICH CONTAIN THE INFORMATION FROM GFM PLUS A COLUMN NAMED HAS_IMPACTFUL WHICH IS TRUE/FALSE DEPENDING WHETHER THE CAMPAIGN CONTAINS AT LEAST ONE IMPACTFUL WORD OR NOT

# %%
gfm_impactful = pd.DataFrame(gfm_campaigns)
gfm_impactful
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# ...

# %%
gfm_impactful.isnull().sum()
# Out:
# Category                   0
# Title                      0
# Location                   0
# Amount_Raised              0
# Goal                       0
# Days_of_Fundraising        0
# Proportion_Raised          0
# Number_of_Donors           0
# FB_Shares                  0
# Text                       0
# Average_Donation_Amount    0
# Num_Chars                  0
# impactful_words            0
# dtype: int64
